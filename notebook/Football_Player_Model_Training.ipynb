# %% [markdown]
# # DATA
# To acess Data please Visit the Link below
# https://drive.google.com/drive/folders/1OXyrE4X_cmSoEYfCm0c49X5KouAWZvsS?usp=sharing

# %% [markdown]
# # Importing

# %%
#set up google drive to access our data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Setting Up Environement

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.4/911.4 kB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %% [markdown]
# # Importing Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="0TWCV0Efjkxv3n0ebdPv")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2732.38it/s]

# %%
# prompt: move this /content/football-players-detection-1 to /content/drive/MyDrive/Football Game Analysis Project cut moving not copying ok

import shutil
import os

source_path = "/content/football-players-detection-1"
destination_path = "/content/drive/MyDrive/Football Game Analysis Project"

if os.path.exists(source_path):
  try:
    shutil.move(source_path, destination_path)
    print(f"Successfully moved '{source_path}' to '{destination_path}'")
  except Exception as e:
    print(f"Error moving directory: {e}")
else:
  print(f"Source directory '{source_path}' does not exist.")
# Out:
# Successfully moved '/content/football-players-detection-1' to '/content/drive/MyDrive/Football Game Analysis Project'

# %% [markdown]
# # Yolov5 Model Training

# %%
# !yolo task=detect mode=train model=yolov5s.pt data=/content/drive/MyDrive/Football\ Game\ Analysis\ Project/football-players-detection-1/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# prompt: move runs/detect/train4 to /content/drive/MyDrive/Football Game Analysis Project please

import shutil
import os

source_path = "runs/detect/train4"
destination_path = "/content/drive/MyDrive/Football Game Analysis Project"

destination_path = os.path.join(destination_path, "train4") #added this to avoid errors

if os.path.exists(source_path):
  try:
    shutil.move(source_path, destination_path)
    print(f"Successfully moved '{source_path}' to '{destination_path}'")
  except Exception as e:
    print(f"Error moving directory: {e}")
else:
  print(f"Source directory '{source_path}' does not exist.")
# Out:
# Successfully moved 'runs/detect/train4' to '/content/drive/MyDrive/Football Game Analysis Project/train4'
